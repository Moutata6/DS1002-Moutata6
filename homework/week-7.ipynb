# %% [markdown]
# <a href="https://colab.research.google.com/github/Moutata6/DS1002-Moutata6/blob/main/homework/week-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 7
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.
#
# Load the following dataset into pandas and perform the requested operations in code.
#
# Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
# Load pandas and the data
import pandas as pd
df = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv')

# %%
# show how many rows and columns are in this dataset
df.shape
# Out:
# (25760, 10)

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)
df['duration'] = df['duration'].str.strip("minutes")
df['duration'] = df['duration'].astype('int')

# %%
# Now display the datatypes in the updated dataframe
df.dtypes
# Out:
# duration            int64
# station_A_id        int64
# station_A_name     object
# station_B_id        int64
# station_B_name     object
# bike_id             int64
# user_type           int64
# user_birth_year     int64
# user_gender        object
# tire_size           int64
# dtype: object

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
df['duration'].min()
df['duration'].max()
# Out:
# 1372

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
df2 = df[df.duration <= 60]

# %%
# Now show both the min and max values of the duration column for your new dataset.
df2['duration'].min()
df2['duration'].max()
# Out:
# 60

# %%
# Using the new dataframe, update it so that is ONLY has records where
# the tire_size is 26.
df3 = df2[df2.tire_size == 26]

# %%
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
df4 = df3[df3.user_gender == "Female"]
len(df4)
df4.head(30)
# Out:
#      duration  station_A_id  \
# 18         16            16
# 41         12             3
# 45          1            67
# 52         13            21
# 53         14            21
# 57         11            21
# 75         11            21
# 76         18            22
# 88          6            81
# 89         11             3
# 93          9             3
# 94          9             3
# 95         10             3
# 107         5             3
# 117         8             5
# 142         8             5
# 155        13            30
# 160        21            81
# 161         7             5
# 167         8            30
# 177        16            67
# 184        19             5
# 207        14            15
# 219        14            67
# 220        10            15
# 227        26            22
# 251        10            81
# 261        10            21
# 263         6             5
# 268        11            22
#
#                                         station_A_name  station_B_id  \
# 18                             Steuart St at Market St            42
# 41        Powell St BART Station (Market St at 4th St)             6
# 45   San Francisco Caltrain Station 2  (Townsend St...            64
# 52    Montgomery St BART Station (Market St at 2nd St)            78
# 53    Montgomery St BART Station (Market St at 2nd St)            78
# 57    Montgomery St BART Station (Market St at 2nd St)            61
# 75    Montgomery St BART Station (Market St at 2nd St)            58
# 76                               Howard St at Beale St            72
# 88                                  Berry St at 4th St           130
# 89        Powell St BART Station (Market St at 4th St)            58
# 93        Powell St BART Station (Market St at 4th St)            58
# 94        Powell St BART Station (Market St at 4th St)            58
# 95        Powell St BART Station (Market St at 4th St)            58
# 107       Powell St BART Station (Market St at 4th St)            16
# 117       Powell St BART Station (Market St at 5th St)            47
# 142       Powell St BART Station (Market St at 5th St)            74
# 155     San Francisco Caltrain (Townsend St at 4th St)           136
# 160                                 Berry St at 4th St            55
# 161       Powell St BART Station (Market St at 5th St)            43
# 167     San Francisco Caltrain (Townsend St at 4th St)             5
# 177  San Francisco Caltrain Station 2  (Townsend St...            55
# 184       Powell St BART Station (Market St at 5th St)           144
# 207  San Francisco Ferry Building (Harry Bridges Pl...           116
# 219  San Francisco Caltrain Station 2  (Townsend St...           109
# 220  San Francisco Ferry Building (Harry Bridges Pl...            30
# 227                              Howard St at Beale St           120
# 251                                 Berry St at 4th St            87
# 261   Montgomery St BART Station (Market St at 2nd St)             8
# 263       Powell St BART Station (Market St at 5th St)            58
# 268                              Howard St at Beale St            67
#
#                                         station_B_name  bike_id  user_type  \
# 18       San Francisco City Hall (Polk St at Grove St)     5000          2
# 41                       The Embarcadero at Sansome St     2899          1
# 45                                5th St at Brannan St     2436          2
# 52                                 Folsom St at 9th St     2531          2
# 53                                 Folsom St at 9th St     1502          2
# 57                                 Howard St at 8th St     2918          2
# 75                                Market St at 10th St      316          2
# 76                                 Page St at Scott St     5162          2
# 88                            22nd St Caltrain Station     5224          2
# 89                                Market St at 10th St      192          2
# 93                                Market St at 10th St     1465          1
# 94                                Market St at 10th St      685          1
# 95                                Market St at 10th St     3109          1
# 107                            Steuart St at Market St      593          2
# 117                              4th St at Harrison St     5474          2
# 142                              Laguna St at Hayes St     4968          2
# 155                           23rd St at San Bruno Ave     5574          2
# 160                             Webster St at Grove St     4969          2
# 161  San Francisco Public Library (Grove St at Hyde...     5530          3
# 167       Powell St BART Station (Market St at 5th St)     4968          2
# 177                             Webster St at Grove St     4953          1
# 184                                       Precita Park     4553          1
# 207                          Mississippi St at 17th St     5463          3
# 219                             17th St at Valencia St     5029          1
# 220     San Francisco Caltrain (Townsend St at 4th St)     2960          2
# 227                               Mission Dolores Park     3053          2
# 251                               Folsom St at 13th St     5369          2
# 261                      The Embarcadero at Vallejo St     1544          3
# 263                               Market St at 10th St     2436          2
# 268  San Francisco Caltrain Station 2  (Townsend St...     5536          1
#
#      user_birth_year user_gender  tire_size
# 18              2000      Female         26
# 41              1967      Female         26
# 45              1990      Female         26
# 52              1999      Female         26
# 53              1998      Female         26
# 57              1999      Female         26
# 75              1999      Female         26
# 76              1980      Female         26
# 88              1983      Female         26
# 89              2000      Female         26
# 93              1999      Female         26
# 94              1991      Female         26
# 95              2000      Female         26
# 107             2000      Female         26
# 117             1997      Female         26
# 142             1993      Female         26
# 155             1980      Female         26
# 160             1969      Female         26
# 161             1990      Female         26
# 167             1993      Female         26
# 177             1992      Female         26
# 184             1994      Female         26
# 207             1988      Female         26
# 219             1988      Female         26
# 220             1991      Female         26
# 227             1987      Female         26
# 251             1984      Female         26
# 261             1991      Female         26
# 263             1987      Female         26
# 268             1982      Female         26
