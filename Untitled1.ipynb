# %% [markdown]
# <a href="https://colab.research.google.com/github/Moutata6/DS1002-Moutata6/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get head rows
mock_data.head(3)
# Out:
#    id  first_name  last_name                        email       gender  age
# 0   1        Noam   Aspenlon       naspenlon0@youtube.com         Male   73
# 1   2       Kelby    Pilbury         kpilbury1@eepurl.com         Male   23
# 2   3  Constantia  Sargerson  csargerson2@sourceforge.net  Genderfluid    9

# %%
#get tail data
mock_data.tail()
# Out:
#        id first_name  last_name                      email  gender  age
# 995   996       Maxy    Illsley  millsleyrn@bravesites.com    Male   66
# 996   997      Tonie     Labell       tlabellro@toplist.cz  Female   21
# 997   998       Mano      Tripe            mtriperp@go.com    Male   38
# 998   999     Curtis  Painswick     cpainswickrq@google.fr    Male   18
# 999  1000   Herculie    Raeburn   hraeburnrr@delicious.com    Male   40

# %%
mock_data.loc[901:910]
# Out:
#       id first_name  last_name                      email      gender  age
# 901  902    Frances      Ruggs      fruggsp1@facebook.com  Polygender   23
# 902  903        Mel    Wincott  mwincottp2@altervista.org        Male   39
# 903  904       Rick      Oehme            roehmep3@nhs.uk        Male   26
# 904  905      Hinze     Baynam  hbaynamp4@accuweather.com        Male   45
# 905  906     Wilden     Kynder          wkynderp5@msn.com        Male   81
# 906  907    Garrard  Tomaselli    gtomasellip6@elpais.com        Male   67
# 907  908    Winonah     Record         wrecordp7@jugem.jp      Female   11
# 908  909     Briana     Bisset        bbissetp8@jimdo.com      Female   83
# 909  910      Tiler   Bradbury  tbradburyp9@earthlink.net        Male   58
# 910  911     Andrea   Dahlback       adahlbackpa@uiuc.edu  Polygender   38

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.183000
# std     288.819436    26.203858
# min       1.000000     1.000000
# 25%     250.750000    23.000000
# 50%     500.500000    44.500000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
#get columns for the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})
mock_data.head()
# Out:
#    id       fname      lname                        email       gender  age
# 0   1        Noam   Aspenlon       naspenlon0@youtube.com         Male   73
# 1   2       Kelby    Pilbury         kpilbury1@eepurl.com         Male   23
# 2   3  Constantia  Sargerson  csargerson2@sourceforge.net  Genderfluid    9
# 3   4     Carlina  Lissandre       clissandre3@cdbaby.com       Female   75
# 4   5      Ronnie   Seiffert    rseiffert4@guardian.co.uk         Male   72

# %%
mock_data["fname"]
# Out:
# 0            Noam
# 1           Kelby
# 2      Constantia
# 3         Carlina
# 4          Ronnie
#           ...
# 995          Maxy
# 996         Tonie
# 997          Mano
# 998        Curtis
# 999      Herculie
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0            Noam
# 1           Kelby
# 2      Constantia
# 3         Carlina
# 4          Ronnie
#           ...
# 995          Maxy
# 996         Tonie
# 997          Mano
# 998        Curtis
# 999      Herculie
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[["fname","lname","age"]]
# Out:
#           fname      lname  age
# 0          Noam   Aspenlon   73
# 1         Kelby    Pilbury   23
# 2    Constantia  Sargerson    9
# 3       Carlina  Lissandre   75
# 4        Ronnie   Seiffert   72
# ..          ...        ...  ...
# 995        Maxy    Illsley   66
# 996       Tonie     Labell   21
# 997        Mano      Tripe   38
# 998      Curtis  Painswick   18
# 999    Herculie    Raeburn   40
#
# [1000 rows x 3 columns]

# %%
pd.value_counts(mock_data["gender"]).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(["gender"])["age"].mean()
# Out:
# gender
# Agender        46.250000
# Bigender       40.680000
# Female         44.746725
# Genderfluid    25.312500
# Genderqueer    50.062500
# Male           45.719178
# Non-binary     62.142857
# Polygender     48.882353
# Name: age, dtype: float64
